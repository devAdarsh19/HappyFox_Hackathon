# %%
from pptx import Presentation
from mistralai import Mistral
from fpdf import FPDF
from pdfminer.high_level import extract_text
import mistune
from mistune.renderers.markdown import MarkdownRenderer
import pypandoc
import os
from dotenv import load_dotenv
import csv
import re

# %%
def extract_text_pdf(pdf_path):
    text = extract_text(pdf_path)
    return text

# %%
pdf_path = '../data/pdf/sample_pdf.pdf'
print(extract_text_pdf(pdf_path))
# Out:
# Module-5
#
# Introduction to THUMB instruction set
# Efficient C Programming
#
# Introduction to THUMB instruction set
#
# • Introduction
# • THUMB register usage
# • ARM – THUMB interworking
# • Other branch instructions
# • Data processing instructions
# • Stack instructions
# • Software interrupt instructions
#
# Introduction
#
# • Thumb encodes a subset of the 32-bit ARM instructions into a 16-bit
# instruction set space.
# • Thumb has higher code density—the space taken up in memory by an
# executable program—than ARM.
# • For memory-constrained embedded systems, for example, mobile
#    phones and PDAs, code density is very important.
# • On average, a Thumb implementation of the same code takes up
# around 30% less memory than the equivalent ARM implementation.
# • Each Thumb instruction is related to a 32-bit ARM instruction.
#
# THUMB register usage
#
# ARM-Thumb Interworking
#
# • ARM-Thumb interworking is the name given to the method of linking
# ARM and Thumb code together for both assembly and C/C++.
# • ATPCS defines the ARM and Thumb procedure call standards.
# • To call a Thumb routine from an ARM routine, the core has to change
# state.
# • This state change is shown in the T bit of the cpsr.
# • The BX and BLX branch instructions cause a switch between ARM and
# Thumb state while branching to a routine.
#
# Other Branch Instructions
#
# • There are two variations of the standard branch instruction, or B.
# • The conditional branch instruction is the only conditionally executed
# instruction in Thumb state.
#
# Data Processing Instructions
#
# • The data processing instructions manipulate data within registers.
# • They include move instructions, arithmetic instructions, shifts, logical
# instructions, comparison instructions, and multiply instructions.
# • The Thumb data processing instructions are a subset of the ARM data
# processing instructions.
# • These instructions follow the same style as the equivalent ARM
# instructions.
# • Most Thumb data processing instructions operate on low registers
# and update the cpsr.
#
# Thumb ADD Instruction: Example
#
# Separate Barrel Shift Operations
#
# Single-Register Load-Store Instructions
#
# • The Thumb instruction set supports load and storing registers, or LDR
# and STR.
#
# Multiple-Register Load-Store Instructions
#
# • The Thumb versions of the load-store multiple instructions are
# reduced forms of the ARM load-store multiple instructions.
# • They only support the increment after (IA) addressing mode.
#
# Stack Instructions
#
# • The Thumb stack operations are different from the equivalent ARM
# instructions because they use the more traditional POP and PUSH
# concept.
#
# • The interesting point to note is that there is no stack pointer in the
# instruction. This is because the stack pointer is fixed as register r13 in
# Thumb operations and sp is automatically updated.
#
# Software Interrupt Instruction
#
# • Similar to the ARM equivalent, the Thumb software interrupt (SWI)
# instruction causes a software interrupt exception.
# • If any interrupt or exception flag is raised in Thumb state, the
# processor automatically reverts back to ARM state to handle the
# exception.
# • The Thumb SWI instruction has the same effect and nearly the same
# syntax as the ARM equivalent.
# • It differs in that the SWI number is limited to the range 0 to 255 and it
# is not conditionally executed.
#
# Summary
#
# • All Thumb instructions are 16 bits in length.
#
# • Thumb provides approximately 30% better code density over ARM code.
#
# • Most code written for Thumb is in a high-level language such as C and C++.
#
# • ATPCS defines how ARM and Thumb code call each other, called ARM-Thumb interworking.
#
# • In Thumb, only the branch instructions are conditionally executed. The barrel shift operations
#
# (ASR, LSL, LSR, and ROR) are separate instructions.
#
# • The multiple-register load-store instructions only support the increment after (IA) addressing
#
# mode.
#
# • The Thumb instruction set includes POP and PUSH instructions as stack operations. These
#
# instructions only support a full descending stack.
#
# • There are no Thumb instructions to access the coprocessors, cpsr, and spsr.
#
# Efficient C Programming
#
# • Overview of C Compilers and optimization
#
# • Basic C Data types
#
# • C looping structures
#
# Overview of C Compilers and optimization
#
# • Optimizing code takes time and reduces source code readability.
# • It’s only worth optimizing functions that are frequently executed and
# important for performance.
# • C compilers have to translate your C function literally into assembler
# so that it works for all possible inputs.
# • In practice, many of the input combinations are not possible or won’t
#    occur.
# • Let’s start by looking at an example of the problems the compiler
# faces.
#
# Example: memclr function
#
# • The memclr function clears N bytes of memory at address data.
#
# • No matter how advanced the compiler, it does not
#
# know whether N can be 0 on input or not.
#
# • Therefore the compiler needs to test for this case
# explicitly before the first iteration of the loop.
#
# • The compiler doesn’t know whether the data array
#
# •
#
# pointer is four-byte aligned or not.
# If it is four-byte aligned, then the compiler can clear
# four bytes at a time using an int store rather than a
# char store.
#
# • Nor does it know whether N is a multiple of four or
#
# not.
#
# • The compiler must be conservative and assume all
#
# possible values for N and all possible alignments for
# data.
#
# Overcoming problems faced by compilers
#
# •To write efficient C code, you must be aware of
# areas where the C compiler has to be
# conservative, the limits of the processor
# architecture the C compiler is mapping to, and
# the limits of a specific C compiler.
# •Most of this section covers the first two points
# above and should be applicable to any ARM C
# compiler.
#
# Basic C Data Types
#
# • Let’s start by looking at how ARM compilers handle the basic C data types.
# • There are also differences between the addressing modes available when
#
# loading and storing data of each type.
#
# • ARM processors have 32-bit registers and 32-bit data processing
#
# operations.
#
# • The ARM architecture is a RISC load/store architecture.
# • In other words you must load values from memory into registers before
#
# acting on them.
#
# • There are no arithmetic or logical instructions that manipulate values in
#
# memory directly.
#
# Local Variable Types
#
# • ARMv4-based processors can efficiently load and store 8-, 16-, and
# 32-bit data.
# • However, most ARM data processing operations are 32-bit only.
# • For this reason, you should use a 32-bit datatype, int or long, for local
# variables wherever possible.
# • Avoid using char and short as local variable types, even if you are
# manipulating an 8- or 16-bit value.
# • To see the effect of local variable types, let’s consider a simple
# example.

# %%
def extract_text_ppt(ppt_path):
    ppt = Presentation(ppt_path)
    text = ""
    for slide in ppt.slides:
        for shape in slide.shapes:
            if hasattr(shape, "text"):
                text += shape.text + "\n\n"
    
    return text

# %%
def generate_notes_mistral(text, api_key_mistral):
    
    model = "mistral-large-latest"
    prompt = f"From the text extracted from an edcational document, return detailed and well-structured notes for the same\n{text}"
    
    client = Mistral(api_key=api_key_mistral)
    
    completion = client.chat.complete(
        model=model,
        messages=[
            {
                "role":"user",
                "content": prompt
            }
        ]
    )
    return completion.choices[0].message.content

# %% [markdown]
# **TEST - MARKDOWN -> PDF**

# %%
# import pypandoc

# %%
# pypandoc.convert_text(notes, "pdf", format="md", outputfile="../data/pdf/output.pdf", )

# %% [markdown]
# **Main**

# %%
def main():
    path = os.path.abspath('../data/pdf/sample_pdf.pdf')
    
    ## Generate API key and store in .env file
    # Load Mistral API key
    # load_dotenv("C:\\Users\\ADMIN\\Desktop\\api_key.env")
    # api_key_mistral = os.getenv("MISTRALAI_API_KEY")
    
    filename = os.path.splitext(os.path.split(path)[1])[0]
    file_ext = os.path.splitext(path)[1]
    
    # check if pdf or ppt
    if file_ext == '.pdf':
        notes = extract_text_pdf(path)
    elif file_ext == '.pptx' or file_ext == '.ppt':
        text = extract_text_ppt(path)
        markdown_converter = mistune.create_markdown(renderer=MarkdownRenderer())
        notes = markdown_converter(text)
    
    # This was for notes generation from ppt or pdf
    detailed_notes = generate_notes_mistral(notes, api_key_mistral)
    # pypandoc.convert_text(detailed_notes, 'pdf', 'md', outputfile=f"{filename}_notes.pdf", extra_args=["--pdf-engine=pdflatex"])
    print(detailed_notes)

# %% [markdown]
# **MAIN FOR RESUME FIELD EXTRACTION**

# %%
main()
# Out:
# ### Detailed and Well-Structured Notes
#
# #### Module-5: Introduction to THUMB Instruction Set & Efficient C Programming
#
# ### Introduction to THUMB Instruction Set
#
# #### Introduction
# - **THUMB Instruction Set**: Encodes a subset of 32-bit ARM instructions into a 16-bit instruction set space.
# - **Code Density**: THUMB has higher code density than ARM, which is crucial for memory-constrained embedded systems like mobile phones and PDAs.
# - **Memory Efficiency**: On average, THUMB implementations take up around 30% less memory than ARM implementations.
# - **Relation to ARM**: Each THUMB instruction is related to a 32-bit ARM instruction.
#
# #### THUMB Register Usage
# - **ARM-Thumb Interworking**: Method of linking ARM and Thumb code together for both assembly and C/C++.
# - **ATPCS**: Defines the ARM and Thumb procedure call standards.
# - **State Change**: To call a Thumb routine from an ARM routine, the core changes state, indicated by the T bit of the cpsr.
# - **Branch Instructions**: BX and BLX cause a switch between ARM and Thumb state while branching to a routine.
#
# #### Other Branch Instructions
# - **Conditional Branch**: The only conditionally executed instruction in Thumb state.
#
# #### Data Processing Instructions
# - **Data Manipulation**: Includes move instructions, arithmetic instructions, shifts, logical instructions, comparison instructions, and multiply instructions.
# - **Subset of ARM**: Thumb data processing instructions are a subset of ARM data processing instructions.
# - **Register Operations**: Most Thumb data processing instructions operate on low registers and update the cpsr.
#
# #### Thumb ADD Instruction: Example
# - **Instruction Example**: Demonstrates how the ADD instruction works in Thumb.
#
# #### Separate Barrel Shift Operations
# - **Barrel Shift Operations**: Include ASR, LSL, LSR, and ROR as separate instructions.
#
# #### Single-Register Load-Store Instructions
# - **Load and Store**: Supports load (LDR) and store (STR) instructions.
#
# #### Multiple-Register Load-Store Instructions
# - **Reduced Forms**: Thumb versions are reduced forms of ARM load-store multiple instructions, supporting only the increment after (IA) addressing mode.
#
# #### Stack Instructions
# - **POP and PUSH**: Uses POP and PUSH concepts for stack operations.
# - **Stack Pointer**: Fixed as register r13 in Thumb operations; sp is automatically updated.
#
# #### Software Interrupt Instruction
# - **SWI Instruction**: Causes a software interrupt exception, reverts to ARM state to handle the exception.
# - **Syntax and Range**: SWI number is limited to the range 0 to 255 and is not conditionally executed.
#
# #### Summary
# - **Instruction Size**: All Thumb instructions are 16 bits in length.
# - **Code Density**: Provides approximately 30% better code density over ARM code.
# - **High-Level Languages**: Most Thumb code is written in high-level languages like C and C++.
# - **Interworking**: ATPCS defines ARM-Thumb interworking.
# - **Conditional Execution**: Only branch instructions are conditionally executed.
# - **Barrel Shift Operations**: Separate instructions for ASR, LSL, LSR, and ROR.
# - **Load-Store Instructions**: Support only the increment after (IA) addressing mode.
# - **Stack Operations**: Include POP and PUSH instructions supporting a full descending stack.
# - **Coprocessor Access**: No Thumb instructions to access coprocessors, cpsr, and spsr.
#
# ### Efficient C Programming
#
# #### Overview of C Compilers and Optimization
# - **Optimization**: Takes time and reduces source code readability; worth optimizing frequently executed and performance-critical functions.
# - **Compiler Translation**: C compilers translate C functions into assembler to work for all possible inputs.
# - **Example: memclr Function**:
#   - **Memory Clearing**: Clears N bytes of memory at address data.
#   - **Compiler Challenges**:
#     - Unknown if N can be 0.
#     - Unknown if data array pointer is four-byte aligned.
#     - Unknown if N is a multiple of four.
#     - Must be conservative and assume all possible values for N and data alignments.
#
# #### Overcoming Problems Faced by Compilers
# - **Awareness**: Be aware of areas where the C compiler must be conservative, limits of the processor architecture, and specific C compiler limits.
# - **Applicability**: Most points cover general ARM C compiler issues.
#
# #### Basic C Data Types
# - **ARM Compilers**: Handle basic C data types differently.
# - **Addressing Modes**: Differences in addressing modes for loading and storing data.
# - **ARM Architecture**:
#   - **32-bit Registers**: ARM processors have 32-bit registers and data processing operations.
#   - **RISC Load/Store**: Must load values from memory into registers before acting on them.
#   - **No Direct Memory Manipulation**: No arithmetic or logical instructions manipulate values in memory directly.
#
# #### Local Variable Types
# - **Efficient Data Loading**: ARMv4-based processors efficiently load and store 8-, 16-, and 32-bit data.
# - **32-bit Operations**: Most ARM data processing operations are 32-bit only.
# - **Recommendation**: Use a 32-bit datatype (int or long) for local variables wherever possible.
# - **Avoid Short Datatypes**: Avoid using char and short as local variable types, even for 8- or 16-bit values.
# - **Example**: Demonstrates the effect of local variable types.
#
# These notes provide a structured overview of the THUMB instruction set and efficient C programming, covering key concepts, instructions, and best practices for optimization.
